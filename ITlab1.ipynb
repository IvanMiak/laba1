# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Математическое ожидание(100000 измерений, 6 граней):
#
# 1 кубик: 3.49791
#
# 3 кубика: 10.5032

# %%
n = np.array([i for i in range(1,101)])
bd = np.array([0, 0.0004, 0.0003, 0.0002, 0.0013, 0.0007, 0.0015, 0.0011, 0.0021, 0.002, 0.002, 0.0025, 0.002, 0.0028, 0.0026, 0.004, 0.0024, 0.0033, 0.0039, 0.0042, 0.0049, 0.0044, 0.0055, 0.0038, 0.0054, 0.0047, 0.0057, 0.0054, 0.0068, 0.0052, 0.0071, 0.0062, 0.005, 0.0067, 0.0066, 0.0067, 0.0078, 0.008, 0.0076, 0.0071, 0.0073, 0.0099, 0.0089, 0.0081, 0.0089, 0.01, 0.0104, 0.0096, 0.0091, 0.0093, 0.0094, 0.0097, 0.0112, 0.011, 0.0107, 0.0104, 0.0112, 0.0116, 0.011, 0.0136, 0.01, 0.0129, 0.0122, 0.0118, 0.0119, 0.0112, 0.0136, 0.0135, 0.0136, 0.0144, 0.0143, 0.013, 0.0143, 0.0143, 0.0143, 0.0148, 0.0181, 0.0156, 0.0165, 0.0147, 0.0166, 0.016, 0.0174, 0.016, 0.0159, 0.0189, 0.0184, 0.0171, 0.0162, 0.0154, 0.0166, 0.0189, 0.0171, 0.0186, 0.0178, 0.0187, 0.0211, 0.0172, 0.0174, 0.0208])
pd = np.array([0.0206, 0.0179, 0.0164, 0.017, 0.0187, 0.0186, 0.0173, 0.0186, 0.0178, 0.018, 0.0171, 0.0177, 0.0167, 0.0188, 0.0165, 0.0169, 0.0161, 0.0181, 0.014, 0.0163, 0.0162, 0.0157, 0.0147, 0.0164, 0.0171, 0.0153, 0.0127, 0.0127, 0.0143, 0.0152, 0.0137, 0.0146, 0.0138, 0.0145, 0.0138, 0.0117, 0.0132, 0.0121, 0.0117, 0.0118, 0.0135, 0.0112, 0.0108, 0.0088, 0.0091, 0.0106, 0.0105, 0.0108, 0.0101, 0.0105, 0.0107, 0.0094, 0.0094, 0.0107, 0.0088, 0.0088, 0.0075, 0.0083, 0.0084, 0.0081, 0.0077, 0.0064, 0.0073, 0.0062, 0.0084, 0.007, 0.0062, 0.0068, 0.0068, 0.0066, 0.0062, 0.0061, 0.0055, 0.0046, 0.0054, 0.005, 0.0049, 0.0056, 0.0043, 0.0042, 0.0033, 0.0032, 0.0043, 0.0036, 0.0027, 0.0029, 0.0025, 0.0019, 0.0019, 0.0022, 0.0018, 0.0021, 0.0013, 0.002, 0.0009, 0.001, 0.0004, 0.0004, 0.0005, 0.0001])

plt.scatter(n, bd)
plt.scatter(n, pd)
plt.legend(['бонус','штраф'])
plt.title("распределение вероятности для 1 броска")
# Out:
# Text(0.5, 1.0, 'распределение вероятности для 1 броска')

# %%
n1 = np.array([i for i in range(3,19)])
bd1 = np.array([4e-05, 0.0004, 0.00168, 0.00669, 0.01779, 0.04046, 0.07413, 0.1096, 0.1406, 0.15878, 0.15473, 0.12029, 0.08638, 0.05356, 0.02703, 0.00915])
pd1 = np.array([0.00922, 0.02779, 0.05331, 0.08633, 0.12054, 0.15275, 0.15882, 0.14067, 0.10855, 0.0728, 0.04154, 0.01753, 0.00654, 0.00159, 0.00033, 4e-05])

plt.plot(n1, bd1)
plt.plot(n1, pd1)
plt.legend(['бонус','штраф'])
plt.title("распределение вероятности для тройного броска")
# Out:
# Text(0.5, 1.0, 'распределение вероятности для тройного броска')

# %% [markdown]
# матожидание двойного броска с бонусом и штрафом(100 граней):
#
# бонус: 67.1861
#
# штраф: 33.8513
